# %%
import numpy as np
from scipy.stats import norm
from scipy import stats

# %%
alpha = 0.02
mu = 50
x_bar = 55
n = 12
std = 6

# %%
t_test = (x_bar-mu)/(std/np.sqrt(n))
t_test
# Out:
# np.float64(2.8867513459481287)

# %%
DoF = n - 1
t_critical = stats.t.ppf(1-alpha/2, DoF)

# %%
print("T_Statistic:", t_test)
print("Degree of Freedom:", DoF)
print("Decision Boundary:", t_critical)
# Out:
# T_Statistic: 2.8867513459481287
# Degree of Freedom: 11
# Decision Boundary: 2.7180791838138614

# %%
if (abs(t_test) > t_critical):
    print("Reject null hypothesis")
else:
    print("Null Hypothesis")
# Out:
# Reject null hypothesis
