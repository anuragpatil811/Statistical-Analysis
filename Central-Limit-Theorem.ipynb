# %%
import numpy as np

# %%
X = np.random.random(size=1000)

# %%
import seaborn as sns
sns.kdeplot(X)
# Out:
# <Axes: ylabel='Density'>

# %%
y = np.random.choice(X, size=30)

# %%
y
# Out:
# array([0.94324026, 0.80954747, 0.17067459, 0.44835864, 0.86327633,
#        0.87803977, 0.15587115, 0.63122036, 0.02245181, 0.17067459,
#        0.19058273, 0.30330325, 0.53321319, 0.82841363, 0.03346151,
#        0.17067459, 0.15587115, 0.90804641, 0.90804641, 0.63122036,
#        0.44835864, 0.59951715, 0.19058273, 0.86327633, 0.03346151,
#        0.28363192, 0.15587115, 0.82841363, 0.28363192, 0.77349198])

# %%
sns.kdeplot(y)
# Out:
# <Axes: ylabel='Density'>

# %%
np.mean(y)
# Out:
# np.float64(0.4738808383786657)

# %%
np.median(y)
# Out:
# np.float64(0.44835863967978873)

# %%
from scipy import stats
stats.mode(y)
# Out:
# ModeResult(mode=np.float64(0.15587114692493698), count=np.int64(3))
