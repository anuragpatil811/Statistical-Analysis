# %%
l = [60, 65, 70, 68, 67, 100]
l1 = [70, 75, 80, 79, 76, 20]
l2 = [1, 2, 3, 3, 3, 4, 5]

# %%
import seaborn as sns

# %%
sns.kdeplot(l)
# Out:
# <Axes: ylabel='Density'>

# %%
from scipy.stats import skew

# %%
skew(l)
# Out:
# np.float64(1.553857733074746)

# %%
import numpy as np

# %%
np.mean(l), np.median(l)
# Out:
# (np.float64(71.66666666666667), np.float64(67.5))

# %%
from scipy.stats import kurtosis

# %%
kurtosis(l)
# Out:
# np.float64(0.8286025196163282)

# %%
#FOR LIST ONE
skew(l1)
# Out:
# np.float64(-1.6985325326026466)

# %%
np.mean(l1), np.median(l1)9
# Out:
# (np.float64(66.66666666666667), np.float64(75.5))

# %%
#Kurtosis = 
kurtosis(l1) + 3
# Out:
# np.float64(4.032179928067075)

# %%
sns.kdeplot(l1)
# Out:
# <Axes: ylabel='Density'>

# %%
#FOR LIST TWO
#Skewness = 
skew(l2)
# Out:
# np.float64(0.0)

# %%
np.mean(l2), np.median(l2)
# Out:
# (np.float64(3.0), np.float64(3.0))

# %%
#Kurtosis = 
kurtosis(l2) + 3
# Out:
# np.float64(2.38)

# %%
sns.kdeplot(l2)
# Out:
# <Axes: ylabel='Density'>
