# %%
import numpy as np

# %%
X = [1, 2, 3, 4]
Y = [2, 2.5, 3.5, 3]

# %%
#CO-VARIANCE
np.cov(X, Y)
# Out:
# array([[1.66666667, 0.66666667],
#        [0.66666667, 0.41666667]])

# %%
#CO-RELATION
np.corrcoef(X, Y)
# Out:
# array([[1. , 0.8],
#        [0.8, 1. ]])

# %%
import seaborn as sns 
sns.scatterplot(x=X, y=Y)
# Out:
# <Axes: >
